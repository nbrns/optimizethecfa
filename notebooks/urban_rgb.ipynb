# %%
import scipy.io 
import numpy as np

# %%
mat = scipy.io.loadmat('../takes/u4c/labels.mat')

# %%
bands = mat['SlectBands']

# %%
r = 13
g = 9
b = 0

# %%
r, g, b
# Out:
# (13, 9, 0)

# %%
mat['Y'].max()
# Out:
# 1000

# %%
ch_0 = mat['Y'][[r,g,b]].reshape((3,307,307))

# %%
import matplotlib.pyplot as plt

# %%
np.max(ch_0)
# Out:
# 812

# %%
ch_0 = np.float64(ch_0)

# %%
import numpy as np

# %%
img = np.moveaxis(ch_0,0,-1).clip(0,255).astype('uint8')
plt.imshow(img)

# %%
plt.imsave('urban_rgb.png', img)

# %%
gt = scipy.io.loadmat('../takes/u4c/labels.mat')

# %%
l_0 = gt['A'].reshape((4,307,307))
l_0 = np.argmax(l_0, axis=0)

# %%
# road, grass, tree, roof
label = 0
mask = l_0 == label
l_0[mask] = 1
l_0[np.logical_not(mask)] = 0

# %%
plt.imshow(l_0, cmap='binary_r')

# %%
plt.imsave(f'labels_{label}.png', l_0, cmap = 'binary_r')
